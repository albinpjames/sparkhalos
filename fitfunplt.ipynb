# %%
from sparkhalos.hstats.fitfun import gev, gevold

import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

import numpy as np

x_value = np.arange(-1,3,0.1)
y_value = gevold(x_value,0,2,0.4)
plt.plot(x_value, y_value)
# Out:
# /mnt/dark/Projects/3.CUSAT/sparkhalos/sparkhalos/hstats/fitfun.py:36: RuntimeWarning: divide by zero encountered in log
#   t = (1 + (xi *(np.log(x+1) - nu_g)/sig_g) )
